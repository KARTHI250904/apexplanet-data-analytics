# %%
from db_utils import fetch_data

query = """
SELECT Category,
       ROUND(SUM(Sales),2) AS Total_Sales
FROM superstore_cleaned
GROUP BY Category;
"""

df = fetch_data(query)
print(df)
# Out:
#           Category  Total_Sales
# 0        Furniture    133375.35
# 1  Office Supplies    188251.95
# 2       Technology    118307.40

# %%
query="""
SELECT Region,
    ROUND(SUM(Sales),2) AS Total_Sales
FROM superstore_cleaned
GROUP BY Region
ORDER BY Total_Sales DESC;
"""
df=fetch_data(query)
print(df)
# Out:
#     Region  Total_Sales
# 0     West    168750.26
# 1     East    110712.96
# 2  Central     90449.63
# 3    South     70021.84
